# %%
import torch

def load_torch_checkpoint(file_path):
    """
    Load a PyTorch checkpoint from a given file path.
    
    Args:
    file_path (str): Path to the checkpoint file.
    
    Returns:
    dict: The loaded checkpoint as a dictionary.
    """
    try:
        checkpoint = torch.load(file_path, map_location=torch.device('cpu'))
        print(f"Successfully loaded checkpoint from {file_path}")
        return checkpoint
    except Exception as e:
        print(f"Error loading checkpoint from {file_path}: {str(e)}")
        return None

# %%
ckpt_base =  '/home/yingqi/repo/hmt_pretrained/opt-350m'
ckpt1 = load_torch_checkpoint(f'{ckpt_base}/model_weights_0_lv_4_step2.pth')
ckpt2 = load_torch_checkpoint(f'{ckpt_base}/model_weights_700_lv_1_step2.pth')
# Out:
# Successfully loaded checkpoint from /home/yingqi/repo/hmt_pretrained/opt-350m/model_weights_0_lv_4_step2.pth
# Successfully loaded checkpoint from /home/yingqi/repo/hmt_pretrained/opt-350m/model_weights_700_lv_1_step2.pth

# %%
print(ckpt1.keys())
print(ckpt2.keys())
# Out:
# odict_keys(['module.mem', 'module.memory_cell.memory', 'module.memory_cell.model.model.decoder.embed_tokens.weight', 'module.memory_cell.model.model.decoder.embed_positions.weight', 'module.memory_cell.model.model.decoder.project_out.weight', 'module.memory_cell.model.model.decoder.project_in.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.k_proj.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.k_proj.bias', 'module.memory_cell.model.model.decoder.layers.0.self_attn.v_proj.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.v_proj.bias', 'module.memory_cell.model.model.decoder.layers.0.self_attn.q_proj.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.q_proj.bias', 'module.memory_cell.model.model.decoder.layers.0.self_attn.out_proj.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.out_proj.bias', 'module.memory_cell.model.model.decoder.layers.0.self_attn_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.0.fc1.weight', 'module.memory_cell.model.model.decoder.layers.0.fc1.bias', 'module.memory_cell.model.model.decoder.layers.0.fc2.weight', 'module.memory_cell.model.model.decoder.layers.0.fc2.bias', 'module.memory_cell.model.model.decoder.layers.0.final_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.0.final_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn.k_proj.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn.k_proj.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn.v_proj.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn.v_proj.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn.q_proj.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn.q_proj.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn.out_proj.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn.out_proj.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.1.fc1.weight', 'module.memory_cell.model.model.decoder.layers.1.fc1.bias', 'module.memory_cell.model.model.decoder.layers.1.fc2.weight', 'module.memory_cell.model.model.decoder.layers.1.fc2.bias', 'module.memory_cell.model.model.decoder.layers.1.final_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.1.final_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn.k_proj.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn.k_proj.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn.v_proj.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn.v_proj.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn.q_proj.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn.q_proj.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn.out_proj.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn.out_proj.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.2.fc1.weight', 'module.memory_cell.model.model.decoder.layers.2.fc1.bias', 'module.memory_cell.model.model.decoder.layers.2.fc2.weight', 'module.memory_cell.model.model.decoder.layers.2.fc2.bias', 'module.memory_cell.model.model.decoder.layers.2.final_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.2.final_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.3.self_attn.k_proj.weight', 'module.memory_cell.model.model.decoder.layers.3.self_attn.k_proj.bias', 'module.memory_cell.model.model.decoder.layers.3.self_attn.v_proj.weight', 'module.memory_cell.model.model.decoder.la ...
# odict_keys(['module.mem', 'module.memory_cell.memory', 'module.memory_cell.model.model.decoder.embed_tokens.weight', 'module.memory_cell.model.model.decoder.embed_positions.weight', 'module.memory_cell.model.model.decoder.project_out.weight', 'module.memory_cell.model.model.decoder.project_in.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.k_proj.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.k_proj.bias', 'module.memory_cell.model.model.decoder.layers.0.self_attn.v_proj.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.v_proj.bias', 'module.memory_cell.model.model.decoder.layers.0.self_attn.q_proj.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.q_proj.bias', 'module.memory_cell.model.model.decoder.layers.0.self_attn.out_proj.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn.out_proj.bias', 'module.memory_cell.model.model.decoder.layers.0.self_attn_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.0.self_attn_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.0.fc1.weight', 'module.memory_cell.model.model.decoder.layers.0.fc1.bias', 'module.memory_cell.model.model.decoder.layers.0.fc2.weight', 'module.memory_cell.model.model.decoder.layers.0.fc2.bias', 'module.memory_cell.model.model.decoder.layers.0.final_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.0.final_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn.k_proj.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn.k_proj.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn.v_proj.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn.v_proj.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn.q_proj.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn.q_proj.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn.out_proj.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn.out_proj.bias', 'module.memory_cell.model.model.decoder.layers.1.self_attn_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.1.self_attn_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.1.fc1.weight', 'module.memory_cell.model.model.decoder.layers.1.fc1.bias', 'module.memory_cell.model.model.decoder.layers.1.fc2.weight', 'module.memory_cell.model.model.decoder.layers.1.fc2.bias', 'module.memory_cell.model.model.decoder.layers.1.final_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.1.final_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn.k_proj.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn.k_proj.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn.v_proj.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn.v_proj.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn.q_proj.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn.q_proj.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn.out_proj.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn.out_proj.bias', 'module.memory_cell.model.model.decoder.layers.2.self_attn_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.2.self_attn_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.2.fc1.weight', 'module.memory_cell.model.model.decoder.layers.2.fc1.bias', 'module.memory_cell.model.model.decoder.layers.2.fc2.weight', 'module.memory_cell.model.model.decoder.layers.2.fc2.bias', 'module.memory_cell.model.model.decoder.layers.2.final_layer_norm.weight', 'module.memory_cell.model.model.decoder.layers.2.final_layer_norm.bias', 'module.memory_cell.model.model.decoder.layers.3.self_attn.k_proj.weight', 'module.memory_cell.model.model.decoder.layers.3.self_attn.k_proj.bias', 'module.memory_cell.model.model.decoder.layers.3.self_attn.v_proj.weight', 'module.memory_cell.model.model.decoder.la ...

# %%
def sum_model_weights(checkpoint):
    sums = []
    for key, value in checkpoint.items():
        if isinstance(value, torch.Tensor):
            sums.append(torch.sum(value).item())
    return sums

sums1 = sum_model_weights(ckpt1)
sums2 = sum_model_weights(ckpt2)

print("Sums of model weights for checkpoint 1:")
print(sums1)
print("\nSums of model weights for checkpoint 2:")
print(sums2)
# Out:
# Sums of model weights for checkpoint 1:
# [0.640625, -2.84375, -32000.0, 37.0, 45.5, 18.125, -49.25, 0.3515625, 2.078125, -0.033447265625, -58.0, 1.203125, -6.59375, -0.0296630859375, 1024.0, -2.078125, 700.0, -121.0, 19.25, -0.0859375, 1024.0, 7.1875, -13.8125, 8.125, 14.875, 0.40234375, -37.25, -1.6015625, 1.6796875, -0.11376953125, 1024.0, -2.078125, 776.0, -99.5, -11.75, 0.30078125, 1024.0, 8.875, 26.125, 9.0625, 42.0, -0.09765625, 12.6875, 1.0078125, -6.8125, 0.349609375, 1024.0, -1.9609375, 980.0, -96.0, -7.78125, 0.3203125, 1024.0, 9.375, -19.75, 8.5, -94.5, -1.015625, -17.375, -0.2890625, -1.7265625, 0.10986328125, 1024.0, -0.470703125, 568.0, -101.5, 6.53125, 0.17578125, 1024.0, 6.71875, 32.0, 9.3125, 66.5, 0.1474609375, -1.5625, 1.4609375, 5.3125, 0.333984375, 1024.0, 0.1982421875, 332.0, -95.5, 7.6875, 0.6796875, 1024.0, 2.609375, -53.75, 11.5625, 10.8125, 0.59375, 11.125, -0.69140625, 21.625, 0.2099609375, 1024.0, -0.4921875, 466.0, -89.5, 1.765625, 0.0927734375, 1024.0, 0.421875, 16.875, 13.25, 48.5, 0.0277099609375, 4.375, 2.09375, 9.8125, -0.1669921875, 1024.0, -0.00531005859375, 596.0, -83.0, -1.5, -0.1611328125, 1024.0, -0.142578125, 12.9375, 13.3125, -34.75, 0.4296875, -3.625, 3.96875, -1.140625, 0.2392578125, 1024.0, 0.1826171875, 780.0, -88.5, -1.453125, 0.045654296875, 1024.0, -1.59375, 9.375, 11.3125, 15.875, 0.5390625, -0.52734375, -0.00020885467529296875, 6.96875, -0.0751953125, 1024.0, 1.046875, 215.0, -92.5, -15.1875, -0.1416015625, 1024.0, -3.328125, 45.25, 9.125, -30.25, 0.283203125, -16.625, 2.390625, -7.3125, -0.0849609375, 1024.0, 0.984375, 108.0, -85.5, -12.4375, 0.267578125, 1024.0, -8.25, -15.9375, 8.0625, 11.625, 0.326171875, 5.28125, -1.7265625, 1.421875, -0.0240478515625, 1024.0, 1.2265625, 67.0, -86.0, -5.6875, -0.1953125, 1024.0, -9.5625, 10.6875, 6.0, -90.0, 0.421875, 4.875, -2.75, 17.0, -0.337890625, 1024.0, 4.21875, -792.0, -96.0, 3.640625, 0.11572265625, 1024.0, -14.875, 21.625, 6.25, 55.75, 0.11572265625, -46.75, 0.341796875, 6.6875, -0.4140625, 1024.0, 4.5, -932.0, -89.5, 4.5, -0.3125, 1024.0, -15.6875, 36.75, 5.90625, -69.5, -0.25390625, 41.25, -2.953125, -11.75, -0.208984375, 1024.0, 3.140625, -1160.0, -98.0, -10.1875, 0.259765625, 1024.0, -24.0, 32.0, 4.6875, 5.40625, 0.439453125, 37.25, -1.5390625, -16.75, -0.234375, 1024.0, 0.97265625, -708.0, -93.5, -4.6875, 0.2412109375, 1024.0, -22.25, 36.25, 5.4375, -129.0, -0.671875, -22.0, 1.484375, 1.0390625, 0.0166015625, 1024.0, 1.0703125, -860.0, -89.5, -6.46875, -0.2734375, 1024.0, -21.375, -16.125, 6.53125, -97.5, -0.80078125, 2.96875, -0.1962890625, -3.625, 0.048828125, 1024.0, 1.1953125, -728.0, -84.5, -19.875, -0.1103515625, 1024.0, -17.5, -6.46875, 3.625, -10.0625, 0.423828125, -15.0, 0.87890625, 11.3125, 0.07861328125, 1024.0, 0.197265625, -496.0, -82.5, -9.375, 0.0027313232421875, 1024.0, -13.9375, 12.125, 5.4375, -56.5, -0.1279296875, -22.5, -2.359375, -6.4375, -0.00927734375, 1024.0, 1.7734375, -724.0, -75.5, 8.5625, -0.00537109375, 1024.0, -12.6875, -23.0, 8.0, -67.0, -0.171875, 94.5, -2.328125, 0.021728515625, 0.236328125, 1024.0, 3.421875, -764.0, -66.5, 27.625, -0.234375, 1024.0, -9.4375, 50.5, 11.5625, 2.078125, -0.365234375, 0.2890625, -2.4375, 8.6875, -0.08984375, 1024.0, 3.09375, -780.0, -62.5, 26.375, -0.1142578125, 1024.0, -9.375, -24.25, 10.0625, -82.5, -0.27734375, -19.5, -1.9375, 1.875, -0.06787109375, 1024.0, 3.25, -764.0, -67.0, 0.89453125, 0.056640625, 1024.0, -5.90625, -9.0, 7.0, -31.625, 0.55859375, -30.875, -1.703125, -1.0234375, -0.01239013671875, 1024.0, 0.828125, -660.0, -63.5, 9.25, 0.11328125, 1024.0, -4.90625, -16.875, 3.734375, 67.0, 0.0260009765625, 21.875, -0.28125, -11.0, -0.1220703125, 1024.0, 1.7421875, 350.0, 10.8125, 44.25, 1.3515625, 1024.0, 9.5625, -32000.0, 18.0, 13.8125, -340.0, -352.0]
#
# Sums of model weights for checkpoint 2:
# [0.640625, -2.84375, -32128.0, 36.75, 45.5, 18.25, -48.5, 0.3515625, 1.2890625, -0.032958984375, -58.25, 1.203125, -6.625, -0.029541015625, 1024.0, -2.078125, 700.0, -121.5, 19.125, -0.08642578125, 1024.0, 7.1875, -13.5, 8.0625, 15.0, 0.40625, -37.25, -1.59375, 1.6796875, -0.11328125, 1024.0, -2.078125, 776.0, -99.5, -11.75, 0.30078125, 1024.0, 8.875, 26.125, 9.0625, 41.75, -0.09619140625, 12.6875, 1.0078125, -6.8125, 0.34765625, 1024.0, -1.9609375, 980.0, -96.0, -7.375, 0.3203125, 1024.0, 9.375, -20.0, 8.5, -94.5, -1.0078125, -17.25, -0.275390625, -1.6953125, 0.1123046875, 1024.0, -0.470703125, 568.0, -101.5, 6.40625, 0.17578125, 1024.0, 6.71875, 32.25, 9.3125, 67.5, 0.1513671875, -1.46875, 1.453125, 5.34375, 0.333984375, 1024.0, 0.1962890625, 330.0, -95.5, 8.1875, 0.67578125, 1024.0, 2.609375, -53.75, 11.5625, 10.75, 0.59375, 10.875, -0.6796875, 21.625, 0.2099609375, 1024.0, -0.4921875, 466.0, -89.5, 1.8984375, 0.09423828125, 1024.0, 0.42578125, 17.375, 13.25, 49.0, 0.031005859375, 4.78125, 2.09375, 9.875, -0.166015625, 1024.0, -0.0017852783203125, 596.0, -83.0, -1.4453125, -0.16015625, 1024.0, -0.1376953125, 12.6875, 13.3125, -34.25, 0.427734375, -3.3125, 3.953125, -1.125, 0.23828125, 1024.0, 0.185546875, 780.0, -88.5, -2.25, 0.04638671875, 1024.0, -1.59375, 9.5625, 11.375, 16.375, 0.5390625, -0.36328125, -0.00034332275390625, 7.0, -0.07421875, 1024.0, 1.0546875, 215.0, -92.5, -15.4375, -0.1416015625, 1024.0, -3.3125, 45.25, 9.1875, -30.75, 0.283203125, -16.5, 2.40625, -7.34375, -0.08740234375, 1024.0, 0.984375, 107.0, -85.5, -12.125, 0.267578125, 1024.0, -8.25, -15.625, 8.0625, 11.75, 0.328125, 5.53125, -1.734375, 1.5, -0.025634765625, 1024.0, 1.21875, 67.5, -86.0, -5.59375, -0.1962890625, 1024.0, -9.5625, 10.625, 6.03125, -90.0, 0.419921875, 4.625, -2.75, 16.875, -0.33984375, 1024.0, 4.21875, -788.0, -96.0, 3.5, 0.115234375, 1024.0, -14.875, 20.875, 6.25, 55.0, 0.115234375, -46.75, 0.353515625, 6.78125, -0.4140625, 1024.0, 4.5, -932.0, -89.5, 3.5, -0.310546875, 1024.0, -15.6875, 37.25, 5.9375, -69.0, -0.251953125, 41.0, -2.953125, -11.5625, -0.2099609375, 1024.0, 3.140625, -1160.0, -98.0, -10.25, 0.259765625, 1024.0, -24.0, 32.5, 4.71875, 6.71875, 0.439453125, 37.25, -1.5390625, -16.875, -0.234375, 1024.0, 0.97265625, -708.0, -93.5, -4.625, 0.2412109375, 1024.0, -22.25, 36.25, 5.4375, -129.0, -0.66796875, -21.875, 1.484375, 1.0390625, 0.019287109375, 1024.0, 1.0625, -860.0, -89.5, -6.09375, -0.2734375, 1024.0, -21.375, -16.5, 6.5, -97.5, -0.796875, 2.8125, -0.185546875, -3.828125, 0.048828125, 1024.0, 1.1875, -724.0, -84.5, -19.625, -0.109375, 1024.0, -17.5, -6.625, 3.625, -10.25, 0.42578125, -14.9375, 0.87109375, 11.5, 0.080078125, 1024.0, 0.1904296875, -494.0, -82.5, -9.1875, 0.002044677734375, 1024.0, -13.9375, 12.125, 5.4375, -57.25, -0.1279296875, -22.625, -2.34375, -6.5, -0.0078125, 1024.0, 1.7734375, -720.0, -75.5, 8.625, -0.0028839111328125, 1024.0, -12.6875, -22.625, 8.0, -67.0, -0.1748046875, 94.5, -2.34375, -0.046875, 0.236328125, 1024.0, 3.40625, -764.0, -66.5, 27.25, -0.234375, 1024.0, -9.5, 50.75, 11.5, 1.859375, -0.36328125, 0.265625, -2.453125, 8.8125, -0.08984375, 1024.0, 3.09375, -776.0, -62.5, 26.5, -0.11279296875, 1024.0, -9.375, -24.5, 10.0625, -82.5, -0.279296875, -19.625, -1.9375, 1.8359375, -0.06591796875, 1024.0, 3.234375, -764.0, -67.0, 1.1796875, 0.0556640625, 1024.0, -5.90625, -8.9375, 7.0, -31.25, 0.5625, -31.0, -1.6953125, -1.0859375, -0.01104736328125, 1024.0, 0.82421875, -660.0, -63.5, 8.3125, 0.11376953125, 1024.0, -4.90625, -16.875, 3.734375, 66.5, 0.0267333984375, 21.875, -0.294921875, -11.25, -0.12353515625, 1024.0, 1.734375, 350.0, 10.8125, 43.75, 1.3515625, 1024.0, 9.5625, -32128.0, 18.0, 13.8125, -340.0, -352.0]
